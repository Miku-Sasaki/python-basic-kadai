# %%
# リストの作成
weekly_weather_list = [
    "月曜日は晴れです",
    "火曜日は雨です",
    "水曜日は晴れです",
    "木曜日は晴れです",
    "金曜日は曇りです",
    "土曜日は曇りのち雨です",
    "日曜日は雷雨です"
]

# データの取り出し例（0番目＝月曜日）
print(weekly_weather_list[0])  # 出力: 月曜日は晴れです
# Out:
# 月曜日は晴れです

# %%
# ディクショナリの作成
weather_dict = {
    "mon": "晴れ",
    "tue": "雨",
    "wed": "晴れ",
    "thu": "晴れ",
    "fri": "曇り",
    "sat": "曇りのち雨",
    "sun": "雷雨"
}

# データの取り出し例（キーを指定）
print(weather_dict["mon"])  # 出力: 晴れ
# Out:
# 晴れ
